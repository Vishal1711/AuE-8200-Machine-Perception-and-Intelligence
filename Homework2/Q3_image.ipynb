# %%
# nusc.list_scenes()
# my_scene = nusc.scene[0]
# my_scene
# first_sample_token = my_scene['first_sample_token']
# nusc.render_sample(first_sample_token)
# my_sample = nusc.get('sample', first_sample_token)
# nusc.list_sample(my_sample['token'])
# nusc.render_pointcloud_in_image(my_sample['token'],pointsensor_channel='LIDAR_TOP')

# %%
# 3. Pickup a set of data, including Image, Lidar, and Radar data. Visualize them respectively. If you use Python, you can refer to NuScene dev-kit tutorial reference code.

# %%
# %matplotlib inline
from nuscenes.nuscenes import NuScenes

#nusc = NuScenes(version='v1.0-mini', dataroot='/NuScenes/data/sets/nuscenes/', verbose=True)
#nusc = NuScenes(dataroot='/home/jai/data/sets/nuscenes')
nusc = NuScenes(dataroot='C:\\Users\\jadha\\Machine Perception and Intelligence\\NuScenes\\data\\sets\\nuscenes')
# Out:
# ...
# Loading NuScenes tables for version v1.0-mini...
# 23 category,
# 8 attribute,
# 4 visibility,
# 911 instance,
# 12 sensor,
# 120 calibrated_sensor,
# 31206 ego_pose,
# 8 log,
# 10 scene,
# 404 sample,
# 31206 sample_data,
# 18538 sample_annotation,
# 4 map,
# Done loading in 0.617 seconds.
# ...
# Reverse indexing ...
# Done reverse indexing in 0.1 seconds.
# ...

# %%
nusc.list_scenes()
# Out:
# scene-0061, Parked truck, construction, intersectio... [18-07-24 03:28:47]   19s, singapore-onenorth, #anns:4622
# scene-0103, Many peds right, wait for turning car, ... [18-08-01 19:26:43]   19s, boston-seaport, #anns:2046
# scene-0655, Parking lot, parked cars, jaywalker, be... [18-08-27 15:51:32]   20s, boston-seaport, #anns:2332
# scene-0553, Wait at intersection, bicycle, large tr... [18-08-28 20:48:16]   20s, boston-seaport, #anns:1950
# scene-0757, Arrive at busy intersection, bus, wait ... [18-08-30 19:25:08]   20s, boston-seaport, #anns:592
# scene-0796, Scooter, peds on sidewalk, bus, cars, t... [18-10-02 02:52:24]   20s, singapore-queensto, #anns:708
# scene-0916, Parking lot, bicycle rack, parked bicyc... [18-10-08 07:37:13]   20s, singapore-queensto, #anns:2387
# scene-1077, Night, big street, bus stop, high speed... [18-11-21 11:39:27]   20s, singapore-hollandv, #anns:890
# ...

# %%
my_scene = nusc.scene[2]
my_scene
# Out:
# {'token': '6f83169d067343658251f72e1dd17dbc',
#  'log_token': '881dd2f8aaec49b681eb54be5bf3b3e2',
#  'nbr_samples': 41,
#  'first_sample_token': '8687ba92abd3406aa797115b874ebeba',
#  'last_sample_token': 'dcbe451d383e450786aaad04ab9d3790',
#  'name': 'scene-0553',
#  'description': 'Wait at intersection, bicycle, large truck, peds crossing crosswalk, ped with stroller'}

# %%
first_sample_token = my_scene['first_sample_token']

# %%
my_sample = nusc.get('sample', first_sample_token)
my_sample
# Out:
# {'token': '8687ba92abd3406aa797115b874ebeba',
#  'timestamp': 1535489296047917,
#  'prev': '',
#  'next': '5bbeb4e68d51413f81a370cb33ef27fb',
#  'scene_token': '6f83169d067343658251f72e1dd17dbc',
#  'data': {'RADAR_FRONT': '8906cfbf397d46b8a42eb9a850048d06',
#   'RADAR_FRONT_LEFT': '6540b3a60bda4feb8015fddadb8ca3ed',
#   'RADAR_FRONT_RIGHT': '577e5fac005041599a2d120533a57745',
#   'RADAR_BACK_LEFT': 'f3fcb4c546e04bcf9f631132e58df580',
#   'RADAR_BACK_RIGHT': 'ff716e8bd09549579fb02d068531d044',
#   'LIDAR_TOP': '4484110755904050a880043268149497',
#   'CAM_FRONT': '95a6d6872f9d4d19b7ac55a80943c611',
#   'CAM_FRONT_RIGHT': '23c84189e7f8419391cfcb4ef06a0ba6',
#   'CAM_BACK': '7e067bbb72ab4967a13ee76d58de1403',
#   'CAM_BACK_RIGHT': '565d8528cad546b69064b12895f10e39',
#   'CAM_BACK_LEFT': '5818f1c2bea641e99caa1436b7149477',
#   'CAM_FRONT_LEFT': '0840770248994d37b866b8feb38e559e'},
#  'anns': ['dc3db4323a1d45b6bf9d602917a700f7',
#   'e7e2e4fdb9d14d8f9ac144d0bb2acf4d',
# ...

# %%
nusc.list_sample(my_sample['token'])
# Out:
# Sample: 8687ba92abd3406aa797115b874ebeba
#
# sample_data_token: 8906cfbf397d46b8a42eb9a850048d06, mod: radar, channel: RADAR_FRONT
# sample_data_token: 6540b3a60bda4feb8015fddadb8ca3ed, mod: radar, channel: RADAR_FRONT_LEFT
# sample_data_token: 577e5fac005041599a2d120533a57745, mod: radar, channel: RADAR_FRONT_RIGHT
# sample_data_token: f3fcb4c546e04bcf9f631132e58df580, mod: radar, channel: RADAR_BACK_LEFT
# sample_data_token: ff716e8bd09549579fb02d068531d044, mod: radar, channel: RADAR_BACK_RIGHT
# sample_data_token: 4484110755904050a880043268149497, mod: lidar, channel: LIDAR_TOP
# sample_data_token: 95a6d6872f9d4d19b7ac55a80943c611, mod: camera, channel: CAM_FRONT
# sample_data_token: 23c84189e7f8419391cfcb4ef06a0ba6, mod: camera, channel: CAM_FRONT_RIGHT
# sample_data_token: 7e067bbb72ab4967a13ee76d58de1403, mod: camera, channel: CAM_BACK
# sample_data_token: 565d8528cad546b69064b12895f10e39, mod: camera, channel: CAM_BACK_RIGHT
# ...

# %%
my_sample['data']
# Out:
# {'RADAR_FRONT': '8906cfbf397d46b8a42eb9a850048d06',
#  'RADAR_FRONT_LEFT': '6540b3a60bda4feb8015fddadb8ca3ed',
#  'RADAR_FRONT_RIGHT': '577e5fac005041599a2d120533a57745',
#  'RADAR_BACK_LEFT': 'f3fcb4c546e04bcf9f631132e58df580',
#  'RADAR_BACK_RIGHT': 'ff716e8bd09549579fb02d068531d044',
#  'LIDAR_TOP': '4484110755904050a880043268149497',
#  'CAM_FRONT': '95a6d6872f9d4d19b7ac55a80943c611',
#  'CAM_FRONT_RIGHT': '23c84189e7f8419391cfcb4ef06a0ba6',
#  'CAM_BACK': '7e067bbb72ab4967a13ee76d58de1403',
#  'CAM_BACK_RIGHT': '565d8528cad546b69064b12895f10e39',
#  'CAM_BACK_LEFT': '5818f1c2bea641e99caa1436b7149477',
#  'CAM_FRONT_LEFT': '0840770248994d37b866b8feb38e559e'}

# %%
sensor = 'CAM_FRONT'
cam_front_data = nusc.get('sample_data', my_sample['data'][sensor])
cam_front_data
# Out:
# {'token': '95a6d6872f9d4d19b7ac55a80943c611',
#  'sample_token': '8687ba92abd3406aa797115b874ebeba',
#  'ego_pose_token': '95a6d6872f9d4d19b7ac55a80943c611',
#  'calibrated_sensor_token': '89b9d32d6d084953b8a7a1584e7e21f0',
#  'timestamp': 1535489296012404,
#  'fileformat': 'jpg',
#  'is_key_frame': True,
#  'height': 900,
#  'width': 1600,
#  'filename': 'samples/CAM_FRONT/n008-2018-08-28-16-43-51-0400__CAM_FRONT__1535489296012404.jpg',
#  'prev': '',
#  'next': 'ec449029ce9e402dae21780252c411d9',
#  'sensor_modality': 'camera',
#  'channel': 'CAM_FRONT'}

# %%
nusc.render_sample_data(cam_front_data['token'])

# %% [markdown]
# sensor = 'LIDAR_TOP'
# lidar_top_data = nusc.get('sample_data', my_sample['data'][sensor])
# lidar_top_data

# %%
sensor = 'LIDAR_TOP' 
lidar_top_data = nusc.get('sample_data', my_sample['data'][sensor]) #lidar_top_data
nusc.render_sample_data(lidar_top_data['token'])

# %%
sensor = 'RADAR_FRONT'
radar_front_data = nusc.get('sample_data', my_sample['data'][sensor])
radar_front_data
# Out:
# {'token': '8906cfbf397d46b8a42eb9a850048d06',
#  'sample_token': '8687ba92abd3406aa797115b874ebeba',
#  'ego_pose_token': '8906cfbf397d46b8a42eb9a850048d06',
#  'calibrated_sensor_token': '002db2f624544e67ac879178fbd5937b',
#  'timestamp': 1535489296044866,
#  'fileformat': 'pcd',
#  'is_key_frame': True,
#  'height': 0,
#  'width': 0,
#  'filename': 'samples/RADAR_FRONT/n008-2018-08-28-16-43-51-0400__RADAR_FRONT__1535489296044866.pcd',
#  'prev': '',
#  'next': 'e1229228349c428c8a08caae87a05651',
#  'sensor_modality': 'radar',
#  'channel': 'RADAR_FRONT'}

# %%
nusc.render_sample_data(radar_front_data['token'])

# %%
my_annotation_token = my_sample['anns'][18]
my_annotation_metadata =  nusc.get('sample_annotation', my_annotation_token)
my_annotation_metadata
# Out:
# {'token': 'a3291a7ed2dd48bea51c0f446014817b',
#  'sample_token': '8687ba92abd3406aa797115b874ebeba',
#  'instance_token': '3993afe444aa4497b1fec37c89fcc369',
#  'visibility_token': '2',
#  'attribute_tokens': ['ab83627ff28b465b85c427162dec722f'],
#  'translation': [1242.387, 1096.596, 1.312],
#  'size': [0.673, 0.639, 1.821],
#  'rotation': [0.9495971948588895, 0.0, 0.0, -0.3134727540251755],
#  'prev': '',
#  'next': '5bf68ab2dff048f4a600e5c2d4aaaa5e',
#  'num_lidar_pts': 0,
#  'num_radar_pts': 2,
#  'category_name': 'human.pedestrian.adult'}

# %%
nusc.render_annotation(my_annotation_token)

# %%
my_instance = nusc.instance[345]
my_instance
# Out:
# {'token': '2ef4b4d20b064d34b754f68e48f5a5c2',
#  'category_token': 'fd69059b62a3469fbaef25340c0eab7f',
#  'nbr_annotations': 28,
#  'first_annotation_token': '818f6afa7a404ba0bb79fa079c305842',
#  'last_annotation_token': '54cbf09638aa4b1985aeeb4dac77f62e'}

# %%
instance_token = my_instance['token']
nusc.render_instance(instance_token)

# %%
print("First annotated sample of this instance:")
nusc.render_annotation(my_instance['first_annotation_token'])
# Out:
# First annotated sample of this instance:

# %%
print("Last annotated sample of this instance")
nusc.render_annotation(my_instance['last_annotation_token'])
# Out:
# Last annotated sample of this instance
